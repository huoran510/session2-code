# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/simple-business-2/label_dict.pkl
# /kaggle/input/simple-business-2/model_directory/model_directory/config.json
# /kaggle/input/simple-business-2/model_directory/model_directory/model.safetensors
# /kaggle/input/simple-business/updated_metadata.csv
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4688502.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4651614.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4660693.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4690458.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4800420.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4638844.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4536150.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4597561.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4417747.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4484879.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4463677.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4833840.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4440608.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4790354.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4778488.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4452955.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4561696.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4737199.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4642425.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4559779.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4645131.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4587131.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4539499.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4539399.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4648472.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4661166.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4503767.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4567447.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4615308.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4667384.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4696358.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4505402.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4790560.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4469682.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4728521.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4684537.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4378726.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4777025.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4736536.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4302030.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4534126.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4601792.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4554873.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4793975.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4541445.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4510119.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4608772.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4702968.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4485420.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4582773.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4741530.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4739164.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4537063.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4495555.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4544366.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4600144.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4500274.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4677733.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4542801.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4429652.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4515985.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4535754.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4230898.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4614016.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4783882.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4574804.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4621811.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4609841.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4618746.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4563446.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4535414.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4774955.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4324003.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4667427.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4644765.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4739780.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4629400.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4760278.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4481940.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4709989.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4683065.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4602778.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4569181.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4572138.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4737479.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4782294.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4765276.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4768488.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4719544.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4696750.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4761319.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4749038.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4812413.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4363930.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4721379.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4818307.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4541374.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4830990.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4637455.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4673361.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4673623.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4690675.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4583378.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4580475.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4739493.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4656830.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4562479.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4721403.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4664463.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4811903.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4720295.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4632833.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4466048.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4530235.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4490189.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4797106.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4646071.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4790362.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4646875.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4727314.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4645773.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4657289.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4588181.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4745727.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4734535.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4526733.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4792696.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4644406.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4634145.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4355773.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4670766.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4690238.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4616016.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4569041.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4806626.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4687277.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4698802.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4472272.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4455205.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4777426.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4770255.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4784671.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4497032.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4721820.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4369991.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4661665.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4703510.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4661851.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4501866.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4659138.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4391392.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4656868.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4760335.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4580338.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4558704.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4640109.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4722145.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4298535.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4682041.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4676916.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4673362.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4544000.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4574183.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4648164.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4739441.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4634255.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4539021.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4723262.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4594777.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4662335.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4610740.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4519920.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4749499.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4580195.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4608650.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4525502.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4776879.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4626120.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4640475.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4771184.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4723623.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4646405.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4600533.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4813689.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4632015.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4667174.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4603171.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4810005.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4707571.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4768936.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4576220.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4517669.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4739586.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4669152.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4520606.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4744971.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4647472.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4774875.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4472674.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4511835.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4184448.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4718559.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4519459.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4567565.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4557820.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4311897.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4594355.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4632530.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4638174.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4431098.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4655466.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4503034.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4806789.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4783841.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4470870.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4619228.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4310321.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4713394.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4788343.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4561332.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4709329.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4645363.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4634691.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4697866.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4557887.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4621862.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4599761.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4601902.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4512839.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4798790.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4755595.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4623130.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4681305.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4770881.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4591823.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4815808.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4615026.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4793649.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4733076.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4668549.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4782953.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4612732.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4745742.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4665767.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4277593.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4705855.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4638627.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4743343.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4583065.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4842247.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4689410.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4601134.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4583885.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4782974.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4535104.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4550523.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4556525.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4761424.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4419065.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4673873.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4557914.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4742637.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4623078.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4336632.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4498660.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4495049.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4140715.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4465442.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4534880.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4641039.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4856831.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4413361.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4697923.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4649915.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4677623.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4621255.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4158555.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4597814.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4679841.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4681506.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4824113.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4768185.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4769139.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4606564.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4301506.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4601910.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4516624.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4718638.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4674959.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4650133.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4806883.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4626182.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4520073.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4583488.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4708934.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4636030.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4834651.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4466465.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4524758.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4665276.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4719676.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4847724.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4586443.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4593519.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4479085.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4573136.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4544433.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4751712.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4547444.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4676451.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4664381.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4580387.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4675479.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4316456.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4695321.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4634710.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4536335.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4850471.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4747853.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4825829.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4721300.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4817040.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4843016.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4620493.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4591268.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4466123.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4649835.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4789856.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4514480.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4275677.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4675065.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4655889.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4570700.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4544126.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4528611.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4536108.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4715662.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4469021.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4667462.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4616852.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4731697.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4312466.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4382916.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4641933.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4811737.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4601180.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4676502.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4805350.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4664274.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4399460.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4546666.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4646868.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4809255.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4600476.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4736170.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4522055.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4618236.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4396567.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4824354.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4658914.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4292744.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4544689.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4794695.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4491206.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4747924.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4516775.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4783623.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4466932.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4532390.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4461467.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4461511.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4674513.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4683430.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4538423.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4400394.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4782151.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4702135.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4663823.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4619257.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4632401.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4646450.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4567834.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4653805.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4497868.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4662777.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4660909.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4568888.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4739407.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4638082.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4615577.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4516907.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4713722.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4522060.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4529217.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4699059.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4617576.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4813074.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4477763.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4404008.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4603047.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4566459.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4533857.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4771814.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4679776.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4640908.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4550765.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4752136.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4808730.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4743847.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4546897.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4772185.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4618671.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4559134.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4785514.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4795755.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4706235.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4561811.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4558416.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4681288.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4677237.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4819448.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4768954.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4506546.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4705244.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4175844.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4715484.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4765837.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4676443.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4722824.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4617945.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4667467.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4500308.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4614461.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4755557.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4702160.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4538261.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4207457.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4646737.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4673586.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4652547.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4783987.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4544292.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4551326.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4853645.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4552083.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4568821.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4632754.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4551678.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4589027.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4794902.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4638065.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4659107.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4629506.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4335170.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4578009.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4741019.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4674591.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4793032.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4313578.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4519916.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4809499.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4603375.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4526342.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4464242.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4812768.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4451938.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4615102.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4633320.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4790725.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4540682.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4581226.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4362072.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4709545.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4720385.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4720559.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4652432.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4686207.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4638966.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4829449.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4550305.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4632528.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4564996.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4664303.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4593055.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4652543.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4610938.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4607072.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4417422.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4581592.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4787081.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4791045.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4552130.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4573658.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4542674.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4852982.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4723610.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4709134.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4500441.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4323991.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4679377.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4506085.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4518696.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4662003.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4558898.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4527328.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4807997.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4600691.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4650950.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4582478.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4511136.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4816084.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4501266.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4534332.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4834827.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4638813.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4603835.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4616536.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4649774.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4676274.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4782943.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4619103.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4705005.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4755338.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4549181.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4498336.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4629436.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4527028.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4760633.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4668852.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4447430.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4608406.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4600526.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4404419.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4664741.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4741467.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4822062.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4524841.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4756684.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4843008.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4482103.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4702121.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4516468.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4730727.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4728148.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4728550.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4563343.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4403284.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4379464.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4798353.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4576387.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4732979.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4800148.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4847915.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4610225.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4644171.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4627363.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4220343.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4402229.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4704740.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4671710.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4615932.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4686664.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4549963.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4539004.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4625696.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4517463.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4526899.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4743838.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4552382.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4583202.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4761454.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4697927.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4694538.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4676653.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4623302.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4569193.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4510401.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4539441.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4719061.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4745586.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4550018.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4729615.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4574133.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4746761.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4706644.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4530606.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4616611.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4729622.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4635840.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4521220.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4725294.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4693851.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4619845.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4652778.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4543902.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4475384.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4683049.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4539372.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4730189.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4602997.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4748610.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4655000.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4547999.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4575010.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4546728.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4560619.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4365025.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4613556.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4741450.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4853942.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4677330.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4629344.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4435656.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4612053.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4718821.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4626423.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4728206.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4650896.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4363064.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4513621.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4598595.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4452818.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4377725.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4557742.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4508645.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4659304.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4627217.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4777239.pdf
# ...
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4540975.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4664645.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4695062.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4599866.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4850988.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4592016.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4680545.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4755586.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4799896.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4574888.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4702333.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4829953.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4712045.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4495549.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4598967.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4601090.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4667420.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4462575.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4737109.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4732193.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4825240.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4626719.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4667223.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4605808.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4623252.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4593623.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4477108.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4675533.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4558990.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4659699.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4712081.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4403286.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4710058.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4596243.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4693803.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4636290.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4377498.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4623554.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4418912.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4709513.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4722848.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4725689.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4652668.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4209868.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4123997.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4572797.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4655227.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4560636.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4544281.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4548477.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4574099.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4738227.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4536692.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4611352.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4363050.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4330187.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4534435.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4783213.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4545901.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4605714.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4824571.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4768764.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4692525.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4534311.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4641098.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4546181.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4673315.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4675311.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4853154.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4641278.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4721899.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4543395.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4604355.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4435056.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4542474.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4620608.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4731696.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4561070.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4703528.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4716922.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4734549.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4585982.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4594174.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4831957.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4586565.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4767247.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4750527.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4825238.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4424830.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4818316.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4533993.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4440772.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4510124.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4572931.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4596930.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4401132.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4812503.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4689435.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4646883.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4807139.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4472808.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4575270.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4716987.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4543712.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4719677.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4619160.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4725770.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4698340.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4536285.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4588844.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4666958.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4585126.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4595389.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4589564.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4401394.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4600371.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4541557.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4278723.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4555188.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4620363.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4492295.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4271106.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4701558.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4636407.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4649182.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4414775.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4715375.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4406746.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4714735.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4750601.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4660064.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4737085.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4644512.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4727227.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4618655.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4798479.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4631749.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4462495.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4511521.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4503876.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4511841.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4722388.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4687197.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4775916.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4708323.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4587789.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4520098.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4704848.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4732649.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4612329.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4770580.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4728115.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4664455.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4713360.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4804068.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4808667.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4809407.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4746645.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4328406.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4625150.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4697014.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4648965.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4837259.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4718896.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4623124.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4773344.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4645308.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4598994.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4709149.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4313542.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4761457.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4632055.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4728088.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4592782.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4566126.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4358883.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4743607.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4534139.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4834556.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4600989.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4676993.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4547042.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4644983.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4781242.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4557593.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4509320.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4599367.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4505395.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4788930.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4630720.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4655891.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4627778.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4586219.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4760526.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4588955.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4707550.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4575900.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4593520.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4672513.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4734429.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4608213.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4784902.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4651722.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4630568.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4492656.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4761748.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4803716.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4358037.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4501399.pdf
# /kaggle/input/simple-business/decisions_half/decisions_half/DRN-4782835.pdf

# %%
# !pip install pdfplumber
# !pip install torch
# !pip install transformers
# !pip install PyMuPDF
# Out:
# Collecting pdfplumber
#   Downloading pdfplumber-0.11.3-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 2.1 MB/s eta 0:00:00
# Collecting pdfminer.six==20231228 (from pdfplumber)
#   Downloading pdfminer.six-20231228-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: Pillow>=9.1 in /opt/conda/lib/python3.10/site-packages (from pdfplumber) (9.5.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from pdfminer.six==20231228->pdfplumber) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /opt/conda/lib/python3.10/site-packages (from pdfminer.six==20231228->pdfplumber) (41.0.7)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.10/site-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (1.16.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (2.21)
# Downloading pdfplumber-0.11.3-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 kB 3.8 MB/s eta 0:00:00
# Downloading pdfminer.six-20231228-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 73.0 MB/s eta 0:00:00:00:0100:01
# Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 75.2 MB/s eta 0:00:00:00:01
# Installing collected packages: pypdfium2, pdfminer.six, pdfplumber
# Successfully installed pdfminer.six-20231228 pdfplumber-0.11.3 pypdfium2-4.30.0
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.1.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.13.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch) (2024.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (4.42.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.23.4)
# Requirement already satisfied: numpy<2.0,>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.5.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2024.7.4)
# Collecting PyMuPDF
#   Downloading PyMuPDF-1.24.9-cp310-none-manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting PyMuPDFb==1.24.9 (from PyMuPDF)
#   Downloading PyMuPDFb-1.24.9-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.4 kB)
# Downloading PyMuPDF-1.24.9-cp310-none-manylinux2014_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 45.5 MB/s eta 0:00:0000:0100:01
# Downloading PyMuPDFb-1.24.9-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (15.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 83.3 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: PyMuPDFb, PyMuPDF
# Successfully installed PyMuPDF-1.24.9 PyMuPDFb-1.24.9

# %%
import pdfplumber
import torch
from transformers import BertTokenizer, BertForSequenceClassification
import pickle
import re
import fitz  # PyMuPDF

# %%
excel_path = '/kaggle/input/simple-business/updated_metadata.csv'
pdf_folder = '/kaggle/input/simple-business/decisions_half/decisions_half'
with open('/kaggle/input/simple-business-2/label_dict.pkl', 'rb') as f:
    label_dict = pickle.load(f)

metadata = pd.read_csv(excel_path)

metadata = metadata.dropna(how='all')

unlabeled_indices = metadata[metadata['field'].isna()].index

def clean_text(text):
    text = re.sub(r'<[^>]+>', '', text)
    text = text.lower()
    return text

def extract_what_happened(pdf_path):
    text = ""
    with fitz.open(pdf_path) as doc:
        for page in doc:
            text += page.get_text()
    
    complaint_pattern = r'The complaint\s*((?:[\s\S](?!What happened))*.)'
    complaint_match = re.search(complaint_pattern, text)
    
    happened_pattern = r'What happened\s*([\s\S]*?)(?=What I’ve decided – and why|What I provisionally said|What I provisionally decided – and why)'
    happened_match = re.search(happened_pattern, text)
    
    complaint_text = complaint_match.group(1).strip() if complaint_match else ""
    happened_text = happened_match.group(1).strip() if happened_match else ""
    
    combined_text = complaint_text + " " + happened_text
    
    return combined_text

def process_pdf_file(pdf_path):
    extracted_text = extract_what_happened(pdf_path)
    if extracted_text:
        cleaned_text = clean_text(extracted_text)
        return cleaned_text
    return None

data = []
for index, row in metadata.iterrows():
    file_name = f"{row['decision_id']}.pdf"
    field = row['field']
    pdf_path = os.path.join(pdf_folder, file_name)
    if os.path.exists(pdf_path):
        text = process_pdf_file(pdf_path)
        if text:
            data.append((text, field))
            
# Get class number
num_labels = metadata['field'].nunique()
print(f"num_labels：{num_labels}")

# Extract texts for model prediction
texts = [text for text, field in data if text]

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Initialize the model and tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model_directory_path = '/kaggle/input/simple-business-2/model_directory/model_directory'
model = BertForSequenceClassification.from_pretrained(model_directory_path, num_labels=num_labels)
model.to(device)
model.eval()

# Batch data
batch_size = 16
predicted_labels = []
for i in range(0, len(texts), batch_size):
    batch_texts = texts[i:i+batch_size]
    inputs = tokenizer(batch_texts, padding=True, truncation=True, max_length=512, return_tensors="pt")
    input_ids = inputs['input_ids'].to(device)
    attention_masks = inputs['attention_mask'].to(device)

    with torch.no_grad():
        outputs = model(input_ids, attention_mask=attention_masks)
    batch_predictions = torch.argmax(outputs.logits, dim=1)
    batch_labels = [label_dict[label.item()] for label in batch_predictions.cpu().numpy()]
    predicted_labels.extend(batch_labels)

# Map the prediction back to metadata
metadata.loc[unlabeled_indices, 'field'] = predicted_labels[:len(unlabeled_indices)]

metadata.to_csv('complete_metadata.csv', index=False)
# Out:
# num_labels：10
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
